# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a sample DataFrame
data = {
    "A": [1, 2, 3, 4, 5],
    "B": [5, 4, 3, 2, 1],
    "C": [2, 3, 4, 5, 6],
    "D": [3, 2, 4, 5, 7]
}

df = pd.DataFrame(data)

# Calculate the correlation matrix
correlation_matrix = df.corr()
print(correlation_matrix)

# Visualize the correlation matrix using Seaborn's heatmap
print(plt.figure(figsize=(8, 6)))

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
#           A         B         C         D
# A  1.000000 -1.000000  1.000000  0.904194
# B -1.000000  1.000000 -1.000000 -0.904194
# C  1.000000 -1.000000  1.000000  0.904194
# D  0.904194 -0.904194  0.904194  1.000000
# Figure(800x600)
